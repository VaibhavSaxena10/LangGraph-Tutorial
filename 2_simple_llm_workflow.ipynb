# %%
from langgraph.graph import StateGraph, START, END 
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model ="qwen/qwen3.8-27b")

# %%
#create a State

class LLMState(TypedDict):

    question : str
    answer : str

# %%
def llm_qa(state:LLMState) -> LLMState:
    question = state['question']

    prompt = f'Answer the following question {question}'

    answer = model.invoke(prompt).content 

    state['answer'] = answer

    return state

# %%
#create our graph 

graph = StateGraph(LLMState)

#add nodes 
graph.add_node('llm_qa', llm_qa)

#add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa', END )

workflow = graph.compile()

# %%
#execute 
initial_state = {'question': 'How far is moon from the earth'}

final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# The distance from the Moon to Earth is not constant because the Moon orbits the Earth in an **elliptical** (oval-shaped) path, rather than a perfect circle. Therefore, the distance varies throughout its orbit.
#
# Here are the key measurements:
#
# - **Average distance**: Approximately **384,400 kilometers** (about **238,855 miles**).
# - **Perigee** (closest point to Earth): Approximately **363,300 kilometers** (about **225,700 miles**).
# - **Apogee** (farthest point from Earth): Approximately **405,500 kilometers** (about **252,000 miles**).
#
# So, while the exact distance changes, the **average distance** is commonly cited as roughly **384,400 km** or **238,900 miles**.

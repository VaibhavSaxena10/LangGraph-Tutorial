# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model= ChatGroq(model ='qwen/qwen3.8-27b')

# %%
class BlogState(TypedDict):
    title : str
    outline : str
    content : str

# %%
def create_outline (state : BlogState) -> BlogState:
    title = state['title']

    prompt = f'Generate an detailed outline for a blog on the topic - {title}'

    outline = model.invoke(prompt).content

    state['outline'] = outline 

    return state

# %%
def create_blog (state:BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'write a detailed blog on the title {title}using the following outline \n {outline} '
    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node( 'create_outline', create_outline)
graph.add_node('create_blog', create_blog)

#edges 
graph.add_edge(START,'create_outline' )
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
#execute 
initial_state = {'title' :'Rise of AI in India'}
final_state= workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog post titled **"The Digital Dawn: Unpacking the Rise of AI in India."**\n\nThis outline is structured to guide the reader through the current landscape, the strategic drivers, real-world applications, challenges, and the future trajectory of Artificial Intelligence in the Indian context.\n\n---\n\n### **Blog Title Options:**\n*   *The Digital Dawn: How India is Becoming a Global AI Hub*\n*   *Beyond Hype: The Real Story of AI’s Rise in India*\n*   *From Code to Commerce: Navigating India’s AI Revolution*\n\n### **Target Audience:**\nTech professionals, business leaders, policy makers, students, and general readers interested in the Indian tech ecosystem.\n\n### **Tone:**\nInformative, optimistic yet realistic, analytical, and engaging.\n\n---\n\n### **I. Introduction**\n*   **Hook:** Start with a vivid scenario or statistic.\n    *   *Example:* "In a bustling market in Mumbai, a vendor uses an AI-powered app to dynamically price goods based on demand. In a hospital in Chennai, an AI algorithm detects early signs of diabetes from a simple blood test. This isn’t science fiction; it’s the new reality of India."\n*   **Context:** Briefly explain why AI is no longer just for Silicon Valley. Mention India’s unique position as a major talent pool and a massive consumer market.\n*   **Thesis Statement:** India is transitioning from being a mere outsourcing destination to a global innovation hub for AI, driven by government initiatives, a young demographic, and a booming startup ecosystem.\n*   **Purpose of the Blog:** To explore the drivers, applications, challenges, and future potential of AI in India.\n\n### **II. The Foundation: Why India? Why Now?**\n*   **The Talent Dividend:**\n    *   India’s status as the world’s largest producer of engineers and data scientists.\n    *   The rise of AI education in top institutions (IITs, NITs, AI Institutes like IIT Madras, IIT Bombay).\n*   **Digital Public Infrastructure (DPI):**\n    *   The role of India Stack (Aadhaar, UPI, ONDC) in creating a data-rich environment.\n    *   How ubiquitous mobile internet (Jio effect) has enabled data collection and distribution.\n*   **The Startup Ecosystem:**\n    *   India’s ranking as a top global startup hub.\n    *   The shift from "AI-enabled" startups to "AI-native" startups.\n    *   Venture Capital investment trends in Indian AI startups.\n\n### **III. Government Strategy: The National AI Mission**\n*   **Policy Frameworks:**\n    *   Launch of the **National Programme on AI (NPAI)**.\n    *   Establishment of the **Institute of Artificial Intelligence for Social Action (IAISA)**.\n*   **Key Focus Areas:**\n    *   **AI for Social Good:** Healthcare, agriculture, education, and disaster management.\n    *   **Governance and Ethics:** Developing a responsible AI framework to ensure transparency, fairness, and privacy.\n*   **Infrastructure Investment:**\n    *   Plans for national AI computing centers.\n    *   Collaboration with private sector for GPU/cloud infrastructure.\n\n### **IV. Key Sectors Driving AI Adoption in India**\n*(Use subheadings for each sector with specific examples)*\n\n1.  **Healthcare:**\n    *   AI in diagnostics (radiology, pathology).\n    *   Personalized medicine and drug discovery.\n    *   *Example:* Startups using AI to analyze medical records for faster insurance claims or early disease detection.\n2.  **Agriculture (AgriTech):**\n    *   Crop monitoring via satellite imagery and drones.\n    *   Predictive analytics for weather and yield.\n    *   Precision farming to reduce resource waste.\n    *   *Example:* AI platforms helping smallholder farmers access fair prices.\n3.  **Finance and Banking (FinTech):**\n    *   Fraud detection and risk assessment.\n    *   Credit scoring for the unbanked population using alternative data.\n    *   Robo-advisors for investment management.\n4.  **Customer Service and Retail:**\n    *   AI-driv ...

# %%
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog post titled **"The Digital Dawn: Unpacking the Rise of AI in India."**
#
# This outline is structured to guide the reader through the current landscape, the strategic drivers, real-world applications, challenges, and the future trajectory of Artificial Intelligence in the Indian context.
#
# ---
#
# ### **Blog Title Options:**
# *   *The Digital Dawn: How India is Becoming a Global AI Hub*
# *   *Beyond Hype: The Real Story of AI’s Rise in India*
# *   *From Code to Commerce: Navigating India’s AI Revolution*
#
# ### **Target Audience:**
# Tech professionals, business leaders, policy makers, students, and general readers interested in the Indian tech ecosystem.
#
# ### **Tone:**
# Informative, optimistic yet realistic, analytical, and engaging.
#
# ---
#
# ### **I. Introduction**
# *   **Hook:** Start with a vivid scenario or statistic.
#     *   *Example:* "In a bustling market in Mumbai, a vendor uses an AI-powered app to dynamically price goods based on demand. In a hospital in Chennai, an AI algorithm detects early signs of diabetes from a simple blood test. This isn’t science fiction; it’s the new reality of India."
# *   **Context:** Briefly explain why AI is no longer just for Silicon Valley. Mention India’s unique position as a major talent pool and a massive consumer market.
# *   **Thesis Statement:** India is transitioning from being a mere outsourcing destination to a global innovation hub for AI, driven by government initiatives, a young demographic, and a booming startup ecosystem.
# *   **Purpose of the Blog:** To explore the drivers, applications, challenges, and future potential of AI in India.
#
# ### **II. The Foundation: Why India? Why Now?**
# *   **The Talent Dividend:**
#     *   India’s status as the world’s largest producer of engineers and data scientists.
#     *   The rise of AI education in top institutions (IITs, NITs, AI Institutes like IIT Madras, IIT Bombay).
# *   **Digital Public Infrastructure (DPI):**
#     *   The role of India Stack (Aadhaar, UPI, ONDC) in creating a data-rich environment.
#     *   How ubiquitous mobile internet (Jio effect) has enabled data collection and distribution.
# *   **The Startup Ecosystem:**
#     *   India’s ranking as a top global startup hub.
#     *   The shift from "AI-enabled" startups to "AI-native" startups.
#     *   Venture Capital investment trends in Indian AI startups.
#
# ### **III. Government Strategy: The National AI Mission**
# *   **Policy Frameworks:**
#     *   Launch of the **National Programme on AI (NPAI)**.
#     *   Establishment of the **Institute of Artificial Intelligence for Social Action (IAISA)**.
# *   **Key Focus Areas:**
#     *   **AI for Social Good:** Healthcare, agriculture, education, and disaster management.
#     *   **Governance and Ethics:** Developing a responsible AI framework to ensure transparency, fairness, and privacy.
# *   **Infrastructure Investment:**
#     *   Plans for national AI computing centers.
#     *   Collaboration with private sector for GPU/cloud infrastructure.
#
# ### **IV. Key Sectors Driving AI Adoption in India**
# *(Use subheadings for each sector with specific examples)*
#
# 1.  **Healthcare:**
#     *   AI in diagnostics (radiology, pathology).
#     *   Personalized medicine and drug discovery.
#     *   *Example:* Startups using AI to analyze medical records for faster insurance claims or early disease detection.
# 2.  **Agriculture (AgriTech):**
#     *   Crop monitoring via satellite imagery and drones.
#     *   Predictive analytics for weather and yield.
#     *   Precision farming to reduce resource waste.
#     *   *Example:* AI platforms helping smallholder farmers access fair prices.
# 3.  **Finance and Banking (FinTech):**
#     *   Fraud detection and risk assessment.
#     *   Credit scoring for the unbanked population using alternative data.
#     *   Robo-advisors for investment management.
# 4.  **Customer Service and Retail:**
#     *   AI-driven chatbots in multiple Indian languages (Hindi, Tamil, Bengali, etc.).
#     *   Personalized recommendations for e-commerce.
#     *   Voice commerce for non-English speaking users.
# 5.  **Education (EdTech):**
#     *   Adaptive learning platforms that tailor content to student pace.
#     *   Automated grading and feedback.
#     *   Language translation tools for inclusive education.
#
# ### **V. The Human Element: AI in Multilingual India**
# *   **The Challenge of Diversity:** India has 22 official languages and hundreds of dialects.
# *   **AI’s Role in Bridging the Gap:**
#     *   Development of NLP (Natural Language Processing) models for low-resource languages.
#     *   Making AI accessible to the "Bharat" (rural/semi-urban) population, not just urban elites.
#     *   *Highlight:* Projects by ISRO, IITs, and startups working on Indic language AI models.
#
# ### **VI. Challenges and Hurdles**
# *   **Data Privacy and Security:**
#     *   Concerns about data misuse, especially with the DPDP (Digital Personal Data Protection) Act.
#     *   Balancing innovation with citizen privacy.
# *   **Infrastructure Gaps:**
#     *   Lack of high-performance computing centers compared to US/China.
#     *   Energy costs and sustainability of AI data centers.
# *   **Talent Retention:**
#     *   Brain drain to US/EU companies.
#     *   Need for upskilling the workforce beyond coding.
# *   **Ethical and Social Concerns:**
#     *   Bias in algorithms (e.g., in lending or hiring).
#     *   Job displacement fears in sectors like customer support and data entry.
#     *   Need for robust AI governance.
#
# ### **VII. The Future: Where is India Headed?**
# *   **AI for Public Services:**
#     *   Envisioning AI-powered governance (e.g., predictive policing, smart cities).
# *   **Global Leadership:**
#     *   India’s potential to lead in "Responsible AI" and "AI for Social Impact."
#     *   Exporting AI solutions from India to the Global South.
# *   **Convergence with Other Tech:**
#     *   AI + 5G/6G.
#     *   AI + IoT (Internet of Things).
#     *   AI + Blockchain for secure data sharing.
#
# ### **VIII. Conclusion**
# *   **Summary:** Recap the key points: strong talent base, supportive government, diverse applications, and significant challenges.
# *   **Call to Action (CTA):**
#     *   For **Businesses:** "Start small, scale smart. Integrate AI ethically."
#     *   For **Policymakers:** "Build frameworks that foster innovation while protecting citizens."
#     *   For **Individuals:** "Upskill. The future belongs to those who can collaborate with AI."
# *   **Closing Thought:** An inspiring statement about India’s AI journey being not just a technological shift, but a social transformation that could redefine development.
#
# ---
#
# ### **Additional Elements to Include in the Blog:**
# *   **Infographics:**
#     *   Map of major AI hubs in India (Bengaluru, Hyderabad, Mumbai, Pune, Delhi).
#     *   Chart showing growth of AI startups in India (2018-2024).
#     *   Sector-wise AI adoption rate.
# *   **Expert Quotes:** Interview snippets from Indian AI researchers, startup founders, or government officials.
# *   **Case Studies:** Brief deep-dives into 2-3 successful Indian AI startups (e.g., **Exotel** for voice AI, **Meesho** for recommendation engines, **Practo** for healthcare AI).
# *   **FAQ Section:**
#     *   *What is the difference between AI, ML, and Deep Learning?*
#     *   *Is AI job-killing in India?*
#     *   *How can I start a career in AI in India?*
#
# ### **SEO Keywords to Target:**
# *   Rise of AI in India
# *   India AI startups
# *   National AI Mission India
# *   AI in Indian healthcare/agriculture
# *   Responsible AI framework India
# *   Digital India AI
# *   Multilingual AI India
#
# This outline provides a comprehensive structure that balances technical depth with accessible storytelling, ensuring the blog is both informative and engaging for a broad audience.

# %%
print(final_state['content'])
# Out:
# # The Digital Dawn: How India is Becoming a Global AI Hub
#
# In a bustling market in Mumbai, a vendor uses an AI-powered app to dynamically price goods based on real-time demand. In a hospital in Chennai, an AI algorithm detects early signs of diabetes from a simple blood test, flagging it to a doctor before symptoms even appear. In a village in Madhya Pradesh, a farmer consults a voice-activated assistant in Marathi to check crop health via satellite imagery.
#
# This isn’t science fiction; it’s the new reality of India.
#
# For decades, India’s relationship with technology was defined by outsourcing—writing code for the West. But that era is fading. Today, the narrative is shifting from "code" to "commerce" and "creation." Artificial Intelligence (AI) is no longer just a tool for Silicon Valley giants; it is becoming the backbone of India’s economic engine.
#
# Driven by a massive talent pool, a supportive government strategy, and a booming startup ecosystem, India is transitioning from a service destination to a global innovation hub for AI. This blog unpacks the drivers, applications, challenges, and future trajectory of this digital revolution.
#
# ---
#
# ## II. The Foundation: Why India? Why Now?
#
# The rise of AI in India isn’t an accident; it is the result of three converging pillars: talent, infrastructure, and enterprise.
#
# ### 1. The Talent Dividend
# India remains the world’s largest producer of engineers. But more importantly, the quality of this talent is evolving. Top institutions like the IITs (Indian Institutes of Technology) and NITs have integrated machine learning and deep learning into their core curricula. With millions of graduates entering the job market annually, India offers a depth of skilled labor that few other nations can match. This "talent dividend" ensures that AI research and development can scale rapidly.
#
# ### 2. Digital Public Infrastructure (DPI)
# Perhaps India’s most unique asset is its **India Stack**—a suite of digital public infrastructure including **Aadhaar** (biometric ID), **UPI** (Unified Payments Interface), and **ONDC** (Open Network for Digital Commerce).
# *   **Data-Rich Environment:** UPI processes billions of transactions daily, creating a rich dataset for financial AI.
# *   **The Jio Effect:** The democratization of mobile internet has brought hundreds of millions of Indians online. This ubiquitous connectivity allows for real-time data collection and distribution, enabling AI models to be trained on diverse, localized data rather than just English-centric datasets.
#
# ### 3. The Startup Ecosystem
# India is now ranked among the top three startup hubs globally. The focus has shifted from "AI-enabled" startups (using AI as a feature) to "AI-native" startups (built entirely on AI models). Venture capital interest in Indian AI startups has surged, with investors betting on solutions that leverage India’s unique scale and complexity to create globally scalable products.
#
# > **Infographic Idea:** *Map of Major AI Hubs in India* highlighting Bengaluru (the tech capital), Hyderabad (genomic and data sciences), Mumbai (finance and startups), Pune (engineering and manufacturing AI), and Delhi-NCR (policy and defense AI).
#
# ---
#
# ## III. Government Strategy: The National AI Mission
#
# The Indian government has moved beyond rhetoric to concrete action, recognizing AI as a strategic imperative for national security and economic growth.
#
# ### Policy Frameworks
# *   **National Programme on AI (NPAI):** This initiative aims to foster innovation in AI across critical sectors. It provides funding for research, incubation, and skill development.
# *   **Institute of Artificial Intelligence for Social Action (IAISA):** Established to focus on AI applications that benefit society, particularly in healthcare, agriculture, and disaster management.
#
# ### Key Focus Areas
# 1.  **AI for Social Good:** The government is prioritizing AI in sectors where public impact is highest. For example, AI models are being developed to predict monsoon patterns more accurately and to optimize vaccine distribution.
# 2.  **Governance and Ethics:** Acknowledging the risks of unchecked AI, India is working on a **Responsible AI Framework**. This aims to ensure that AI systems are transparent, fair, and respectful of privacy, setting a standard that could influence global policy.
#
# ### Infrastructure Investment
# Recognizing the compute-heavy nature of AI, the government is exploring the establishment of national AI computing centers. By collaborating with private cloud providers, India aims to reduce the cost of high-performance computing (HPC) for researchers and startups, ensuring that compute power is not a bottleneck for innovation.
#
# ---
#
# ## IV. Key Sectors Driving AI Adoption in India
#
# AI in India is not abstract; it is deeply embedded in the fabric of daily life. Here’s how key sectors are leveraging this technology.
#
# ### 1. Healthcare: From Reactive to Predictive
# India’s healthcare system is vast and fragmented. AI is helping bridge gaps in diagnostics and access.
# *   **Diagnostics:** Startups are using AI to analyze radiology scans (X-rays, MRIs) with high accuracy, helping radiologists detect early signs of cancer or pneumonia.
# *   **Insurance and Claims:** AI automates the verification of medical claims, reducing fraud and speeding up payouts for patients.
# *   **Case Study:** **Practo**, a leading healthcare platform, uses AI to route patients to the right specialists and predict patient health trends based on historical data.
#
# ### 2. Agriculture (AgriTech): Empowering the Farmer
# With over 50% of the population engaged in agriculture, AI is transforming this sector from subsistence to precision farming.
# *   **Crop Monitoring:** Satellite imagery and drone data are analyzed to monitor crop health, detect pest infestations, and estimate yields.
# *   **Market Access:** AI platforms help smallholder farmers access fair market prices by aggregating demand and supply data, reducing exploitation by middlemen.
# *   **Example:** Platforms like **DeHaat** use AI to provide personalized advice to farmers on sowing, spraying, and harvesting, significantly improving yields.
#
# ### 3. Finance and Banking (FinTech): Inclusion at Scale
# *   **Credit Scoring:** Traditional credit scoring fails millions of unbanked Indians. AI models now use alternative data (utility bills, mobile usage, transaction patterns) to assess creditworthiness, enabling banks to lend to the informal economy.
# *   **Fraud Detection:** Real-time AI algorithms monitor millions of UPI transactions to flag suspicious activity instantly, securing the digital payment ecosystem.
#
# ### 4. Customer Service and Retail: The Voice of Bharat
# *   **Multilingual Chatbots:** Instead of relying on English-only support, Indian companies are deploying AI chatbots that understand Hindi, Tamil, Bengali, and other regional languages.
# *   **Voice Commerce:** For users who may not be comfortable typing, voice-based shopping assistants are driving e-commerce growth in Tier 2 and Tier 3 cities.
#
# ### 5. Education (EdTech): Personalized Learning
# *   **Adaptive Learning:** AI platforms tailor educational content to each student’s pace and learning style, identifying weak areas and providing targeted practice.
# *   **Inclusivity:** Language translation tools make high-quality educational content accessible to students who do not speak English, democratizing education.
#
# > **Case Study:** **Meesho**, India’s largest social commerce platform, uses AI recommendation engines to show users products they are likely to buy, increasing conversion rates while keeping prices low.
#
# ---
#
# ## V. The Human Element: AI in Multilingual India
#
# One of the most significant challenges and opportunities for AI in India is its linguistic diversity. With 22 scheduled languages and hundreds of dialects, building a "one-size-fits-all" AI model is impossible.
#
# ### Bridging the Gap
# *   **Low-Resource Languages:** Historically, NLP (Natural Language Processing) models have been biased toward English, Mandarin, and Spanish. Indian institutions like ISRO and IITs are pioneering the development of AI models for Indic languages.
# *   **Accessing "Bharat":** The term "Bharat" refers to rural and semi-urban India. By making AI accessible in local languages, India is ensuring that the benefits of AI are not limited to urban elites. A farmer in Punjab can now interact with a weather prediction AI in Punjabi, just as a banker in Mumbai does in English.
#
# This focus on multilingual AI is not just a technical achievement; it is a social equity initiative.
#
# ---
#
# ## VI. Challenges and Hurdles
#
# While the momentum is strong, India’s AI journey is not without significant obstacles.
#
# ### 1. Data Privacy and Security
# The passage of the **Digital Personal Data Protection (DPDP) Act** is a landmark step, but implementation remains complex. Balancing the need for data to train AI models with the right to privacy is a delicate tightrope walk. Companies must ensure that data is anonymized and used ethically, avoiding misuse that could erode public trust.
#
# ### 2. Infrastructure Gaps
# *   **Compute Power:** India lags behind the US and China in the availability of high-performance computing centers. Training large language models (LLMs) requires massive GPU clusters, which are expensive and energy-intensive.
# *   **Energy Costs:** The sustainability of AI data centers is a growing concern. India must invest in renewable energy sources to power its AI infrastructure without exacerbating its carbon footprint.
#
# ### 3. Talent Retention
# While India produces top AI talent, many of the best minds are poached by companies in the US and Europe. Retaining this talent requires competitive salaries, research funding, and an ecosystem that supports long-term innovation, not just short-term outsourcing projects.
#
# ### 4. Ethical and Social Concerns
# *   **Algorithmic Bias:** AI models trained on biased data
